# %%
from ColabTurtlePlus.Turtle import *

clearscreen()
setup(1000,800)
nome = Turtle()
nome.speed(7)


nome.left(90)
nome.forward (100) 
nome.right (90)
nome.forward (100)
nome.penup()
nome.backward(100)
nome.right (90)
nome.forward(50)
nome.left (90)
nome.pendown()
nome.forward(100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_336/3495991730.py in <cell line: 0>()
# ----> 1 from ColabTurtlePlus.Turtle import *
#       2
#       3 clearscreen()
#       4 setup(1000,800)
#       5 nome = Turtle()
#
# ModuleNotFoundError: No module named 'ColabTurtlePlus'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
